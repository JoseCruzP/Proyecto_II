# %% [markdown]
# El EDA (Exploratory Data Analysis o Análisis Exploratorio de Datos), tiene como objetivo comprender las principales características del conjunto de datos antes de aplicar los modelos predictivos o realizar análisis estadísticos más profundos. El EDA permite descubrir patrones, detectar anomalías, verificar supuestos y probar hipótesis.

# %% [markdown]
# # **1. Carga del dataset Telefonia_movil_final**

# %%
import pandas as pd

telefonia_movil_df = pd.read_excel('/content/Telefonia_movil_final.xlsx')

# %%
# Verificamos los nombres de las hojas disponibles en el archivo
telefonia_movil_xls = pd.ExcelFile('/content/Telefonia_movil_final.xlsx')
telefonia_movil_xls.sheet_names
# Out:
# ['Accesos', 'Minutos salientes', 'Ingresos']

# %% [markdown]
# # **2. Análisis exploratorio hoja `Accesos`**

# %% [markdown]
# ## 2.1. Carga de la hoja

# %%
# Cargamos la hoja 'Accesos'
accesos_df = pd.read_excel('/content/Telefonia_movil_final.xlsx', sheet_name='Accesos')

# Mostramos las primeras filas del dataset
accesos_df.head()
# Out:
#     año  trimestre  total_de_accesos_pospago  total_de_accesos_prepago  \
# 0  2013          1                 7761349.0                57147608.0
# 1  2013          2                 7769110.0                58004822.0
# 2  2013          3                 8002183.0                59048909.0
# 3  2013          4                 8674516.0                58894516.0
# 4  2014          1                 8224482.0                54725089.0
#
#    total_de_accesos_operativos    periodo
# 0                     64908957 2013-03-31
# 1                     65773932 2013-06-30
# 2                     67051092 2013-09-30
# 3                     67569032 2013-12-31
# 4                     62949571 2013-03-31

# %% [markdown]
# ## 2.2. Estadísticas Descriptivas

# %%
# Resumen estadístico del dataset
accesos_df.describe()
# Out:
#                año  trimestre  total_de_accesos_pospago  \
# count    45.000000  45.000000              4.500000e+01
# mean   2018.133333   2.466667              7.043168e+06
# min    2013.000000   1.000000              5.556299e+06
# 25%    2015.000000   1.000000              6.231309e+06
# 50%    2018.000000   2.000000              7.272585e+06
# 75%    2021.000000   3.000000              7.747230e+06
# max    2024.000000   4.000000              8.674516e+06
# std       3.286335   1.140175              8.912759e+05
#
#        total_de_accesos_prepago  total_de_accesos_operativos  \
# count              4.500000e+01                 4.500000e+01
# mean               5.332569e+07                 6.036887e+07
# min                4.906016e+07                 5.461989e+07
# 25%                5.211002e+07                 5.860644e+07
# 50%                5.310204e+07                 6.057180e+07
# 75%                5.455741e+07                 6.223081e+07
# ...

# %% [markdown]
# **Accesos Pospago**
#
# * **Media:** El promedio de accesos pospago es de aproximadamente $7,04$ millones. Esto refleja una base considerable de usuarios que utilizan planes mensuales con pagos recurrentes.
#
# * **Desviación estándar:** La desviación estándar es de $891.275$ accesos, lo que indica una cierta variabilidad a lo largo del tiempo, pero no una gran dispersión en comparación con los accesos prepago.
#
# * **Mínimo y máximo:**
#
#     + El valor mínimo de accesos pospago es de $5,56$ millones en el primer trimestre de 2013, lo que corresponde a los primeros datos disponibles.
#
#     + El valor máximo es de $8,67$ millones en el primer trimestre de 2024, lo que muestra un crecimiento sostenido en la base de clientes pospago a lo largo del tiempo.
#
# * **Percentiles:**
#
#     + El $25\%$ de los trimestres tiene menos de $6,23$ millones de accesos pospago, lo que sugiere un crecimiento importante a lo largo del tiempo.
#
#     + El $75\%$ de los trimestres tiene más de $7,74$ millones de accesos, lo que indica que la mayoría de los registros se agrupan en niveles más altos en los últimos años.

# %% [markdown]
# **Accesos Prepago**
#
#   * **Media:** El promedio de accesos prepago es de $53,33$ millones, mucho más alto que los accesos pospago, lo que refleja la popularidad de los planes prepago en comparación con los pospago.
#
#   * **Desviación estándar:** La desviación estándar es de $2,37$ millones de accesos, lo que indica una mayor variabilidad en los accesos prepago, probablemente debido a la fluctuación en el uso de estos servicios (las personas tienden a activar y desactivar líneas prepago más frecuentemente).
#
#   * **Mínimo y máximo:**
#
#   El mínimo es de $49,06$ millones de accesos en 2013, mientras que el máximo es de $59,05$ millones de accesos en 2024. Esto muestra que, aunque el prepago sigue siendo el tipo de plan más popular, su crecimiento ha sido más moderado en comparación con los accesos pospago.
#
#   * **Percentiles:**
#
#     + El $25\%$ de los trimestres tiene menos de $52,11$ millones de accesos prepago.
#
#     + El $75\%$ de los trimestres tiene más de $54.55$ millones, lo que muestra un rango bastante amplio y sugiere que los accesos prepago han oscilado de forma notable a lo largo del tiempo.

# %% [markdown]
# **Total de Accesos Operativos**
#
# * **Media:** El promedio de total de accesos operativos (sumando pospago y prepago) es de $60,37$ millones de accesos. Esto refleja la base total de usuarios activos en los servicios de telefonía móvil.
#
# * **Desviación estándar:** La desviación estándar es de $3,11$ millones, lo que indica una cierta fluctuación a lo largo de los años.
#
# * **Mínimo y máximo:**
#
#     + El mínimo fue de $54,62$ millones de accesos en 2013, y el máximo alcanzó $67,57$ millones de accesos en 2024.
#
#     + Este crecimiento total refleja tanto el aumento en los accesos pospago como el prepago, aunque el pospago ha crecido a un ritmo más rápido.
#
# * **Percentiles:**
#
#     + El $25\%$ de los trimestres tiene menos de $58,61$ millones de accesos totales.
#
#     + El $75\%$ de los trimestres tiene más de $62,23$ millones, lo que destaca un crecimiento constante en la base de usuarios móviles operativos.

# %% [markdown]
# **Tendencias Generales**
#
# * **Crecimiento sostenido:** Desde 2013 hasta 2024, los accesos tanto pospago como prepago han mostrado un crecimiento, aunque el crecimiento en los accesos pospago ha sido más notable.
#
# * **Popularidad del prepago:** A lo largo de los años, los accesos prepago han sido consistentemente más altos que los pospago, lo que refleja la preferencia del mercado por los planes flexibles, especialmente en los primeros años del análisis.
#
# * **Crecimiento de los accesos pospago:** El incremento significativo de los accesos pospago en los últimos años podría estar vinculado a un cambio en el comportamiento de los consumidores, quienes prefieren las facilidades y ventajas que ofrecen los contratos pospago.

# %% [markdown]
# ## 2.3. Evolución de los accesos a lo largo del tiempo

# %% [markdown]
# Graficamos cómo han evolucionado los accesos pospago y prepago a lo largo del tiempo.

# %%
import matplotlib.pyplot as plt

# Gráfico de línea para la evolución de los accesos pospago y prepago
plt.figure(figsize=(10, 6))
plt.plot(accesos_df['periodo'], accesos_df['total_de_accesos_pospago'], label='Pospago')
plt.plot(accesos_df['periodo'], accesos_df['total_de_accesos_prepago'], label='Prepago')
plt.title('Evolución de los accesos a telefonía móvil')
plt.xlabel('Periodo')
plt.ylabel('Número de accesos')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# **Accesos Prepago (Línea Naranja)**
#
# * **Dominio del prepago:** Desde 2013 hasta 2024, el prepago ha sido consistentemente la modalidad con el mayor número de accesos. A lo largo de este periodo, los accesos prepago siempre han sido significativamente superiores a los accesos pospago.
#
# **Declive gradual:** A partir de aproximadamente 2014, se observa un declive gradual en los accesos prepago. Aunque sigue siendo la modalidad predominante, la tendencia indica que los usuarios de prepago han ido disminuyendo con el tiempo.
#
# **Estabilización reciente:** En los últimos años (2020-2024), el número de accesos prepago parece haberse estabilizado, oscilando en torno a los $50-55$ millones de accesos. Esto sugiere que el mercado de prepago ha alcanzado un nivel de saturación o estabilidad, con poca variación en los accesos.

# %% [markdown]
# **Accesos Pospago (Línea Azul)**
#
# * **Crecimiento constante:** A diferencia del prepago, los accesos pospago muestran una tendencia ligeramente creciente a lo largo del periodo. Aunque el crecimiento no es tan rápido ni tan pronunciado, es sostenido.
#
# * **Despegue en los últimos años:** El crecimiento más notable en los accesos pospago ocurre después de 2020, cuando la línea azul comienza a elevarse con mayor claridad, alcanzando un pico en 2024. Este aumento refleja una mayor adopción de planes pospago en los últimos años.
#
# * **Pospago como alternativa emergente:** Aunque sigue siendo menor que el prepago, el pospago ha ido ganando terreno, posiblemente debido a los beneficios adicionales que ofrecen estos planes (como datos móviles ilimitados o mejores tarifas en comparación con el prepago).

# %% [markdown]
# ## 2.4. Comparación entre accesos pospago y prepago

# %% [markdown]
# Comparamos los promedios de accesos pospago y prepago para observar la preferencia por cada tipo de servicio.

# %%
# Comparamos los promedios de accesos pospago y prepago
accesos_df[['total_de_accesos_pospago', 'total_de_accesos_prepago']].mean()
# Out:
# total_de_accesos_pospago    7.043168e+06
# total_de_accesos_prepago    5.332569e+07
# dtype: float64

# %% [markdown]
# El prepago es la modalidad más utilizada, con aproximadamente $7$ veces más usuarios que los planes pospago, lo que refleja una preferencia clara por los planes sin contrato y de pago por uso, aunque el pospago está presente de manera considerable y ha mostrado un crecimiento en los últimos años.

# %% [markdown]
# # **3. Análisis exploratorio hoja `Minutos salientes`**

# %% [markdown]
# ## 3.1. Carga de la hoja

# %%
# Cargamos la hoja 'Minutos salientes'
minutos_salientes_df = pd.read_excel('/content/Telefonia_movil_final.xlsx', sheet_name='Minutos salientes')

# Mostramos las primeras filas del dataset
minutos_salientes_df.head()
# Out:
#     año  trimestre  minutos_pospago_salientes_miles  \
# 0  2013          1                        8785943.0
# 1  2013          2                        9512689.0
# 2  2013          3                       10315484.0
# 3  2013          4                        9809515.0
# 4  2014          1                       10128751.0
#
#    minutos_prepago_salientes_miles  total_de_minutos_salientes_miles  \
# 0                        6582117.0                        15368060.0
# 1                        7108640.0                        16621329.0
# 2                        7335154.0                        17650638.0
# 3                        6250549.0                        16060064.0
# 4                        5799223.0                        15927974.0
#
#      periodo
# 0 2013-03-31
# 1 2013-06-30
# 2 2013-09-30
# 3 2013-12-31
# 4 2013-03-31

# %% [markdown]
# ## 3.2. Estadísticas Descriptivas

# %%
# Resumen estadístico del dataset
minutos_salientes_df.describe()
# Out:
#                año  trimestre  minutos_pospago_salientes_miles  \
# count    45.000000  45.000000                     4.500000e+01
# mean   2018.133333   2.466667                     1.243137e+07
# min    2013.000000   1.000000                     8.785943e+06
# 25%    2015.000000   1.000000                     1.098098e+07
# 50%    2018.000000   2.000000                     1.236290e+07
# 75%    2021.000000   3.000000                     1.398605e+07
# max    2024.000000   4.000000                     1.596076e+07
# std       3.286335   1.140175                     1.834267e+06
#
#        minutos_prepago_salientes_miles  total_de_minutos_salientes_miles  \
# count                     4.500000e+01                      4.500000e+01
# mean                      5.814966e+06                      1.825630e+07
# min                       3.469826e+06                      1.350752e+07
# 25%                       5.440364e+06                      1.642699e+07
# ...

# %% [markdown]
# **Minutos Pospago Salientes**
#
# * **Media:** El promedio de minutos salientes en planes pospago es de $12,43$ millones de minutos por trimestre. Esto indica un uso constante de los servicios pospago para realizar llamadas.
#
# * **Desviación estándar (std):** La desviación estándar de $1,83$ millones refleja que hay cierta variabilidad en los minutos utilizados, lo que sugiere que algunos trimestres tienen un uso de minutos significativamente mayor que otros.
#
# * **Mínimo y máximo:**
#
#     + El valor mínimo es de $8,79$ millones de minutos en el primer trimestre de 2013, lo que refleja un menor uso en los primeros años del periodo.
#
#     + El valor máximo es de $15,96$ millones de minutos en el primer trimestre de 2024, lo que indica un incremento en el uso de minutos en planes pospago.
#
# * **Percentiles:**
#
#     + El 25% de los trimestres tienen menos de $10,98$ millones de minutos, lo que representa los primeros años con menor uso.
#
#     + El 75% de los trimestres tienen más de $13,98$ millones de minutos, lo que refleja el crecimiento del uso de minutos pospago en los últimos años.

# %% [markdown]
# **Minutos Prepago Salientes**
#
# * **Media:** El promedio de minutos salientes en planes prepago es de $5,81$ millones de minutos, considerablemente menor que en los planes pospago, lo que sugiere que los usuarios de prepago realizan menos llamadas o prefieren otros métodos de comunicación.
#
# * **Desviación estándar (std):** La desviación estándar de $1,21$ millones también indica cierta variabilidad en el uso de minutos prepago.
#
# * **Mínimo y máximo:**
#
#     + El mínimo de $3,46$ millones de minutos en el primer trimestre de 2013 refleja un uso bastante bajo de minutos en planes prepago.
#
#     + El máximo es de $7,33$ millones de minutos en el primer trimestre de 2024, lo que indica que aunque el uso de minutos prepago ha aumentado, no lo ha hecho tan drásticamente como el pospago.
#
# * **Percentiles:**
#
#   El $25\%$ de los trimestres tienen menos de $5,44$ millones de minutos, mientras que el $75\%$ de los trimestres tienen más de $6,61$ millones, lo que muestra que en algunos trimestres el uso de minutos prepago es mucho más bajo en comparación con pospago.

# %% [markdown]
# **Total de Minutos Salientes**
#
# * **Media:** El total promedio de minutos salientes, combinando ambos planes, es de $18,25$ millones de minutos por trimestre.
#
# * **Desviación estándar (std):** Con una desviación estándar de $2,35$ millones de minutos, se observa una variabilidad significativa en los minutos totales utilizados a lo largo de los trimestres.
#
# * **Mínimo y máximo:**
#
#     + El mínimo es de $13,50$ millones de minutos en el primer trimestre de 2013, cuando los servicios de telefonía móvil estaban en una etapa de menor uso.
#
#     + El máximo es de $22,89$ millones de minutos en el primer trimestre de 2024, lo que refleja un crecimiento considerable en el uso total de minutos salientes.
#
# * **Percentiles:**
#
#     + El 25% de los trimestres tienen menos de $16,42$ millones de minutos, lo que representa los trimestres con menor uso.
#
#     + El 75% de los trimestres tienen más de $20,19$ millones de minutos, lo que indica que en la mayoría de los casos se utiliza una cantidad significativa de minutos para realizar llamadas.

# %% [markdown]
# ## 3.3. Evolución de los minutos salientes por modalidad

# %% [markdown]
# Graficamos cómo han evolucionado los minutos salientes tanto en planes pospago como en prepago a lo largo del tiempo.

# %%
# Gráfico de línea para la evolución de los minutos pospago y prepago
plt.figure(figsize=(10, 6))
plt.plot(minutos_salientes_df['periodo'], minutos_salientes_df['minutos_pospago_salientes_miles'], label='Pospago')
plt.plot(minutos_salientes_df['periodo'], minutos_salientes_df['minutos_prepago_salientes_miles'], label='Prepago')
plt.title('Evolución de los minutos salientes en telefonía móvil')
plt.xlabel('Periodo')
plt.ylabel('Minutos salientes (miles)')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# La gráfica muestra la evolución de los minutos salientes en telefonía móvil entre los años 2014 y 2024, con una clara diferenciación entre los planes pospago (línea azul) y prepago (línea naranja).

# %% [markdown]
# **Minutos Pospago (Línea Azul)**
#
# * **Crecimiento inicial:** Entre 2014 y 2016, el uso de minutos en planes pospago experimenta un crecimiento sostenido, alcanzando un pico alrededor de 2016-2017. Esto refleja una mayor adopción de planes pospago o un aumento en el uso de llamadas por parte de los usuarios.
#
# * **Fluctuaciones a partir de 2016:** Después de alcanzar su pico en 2016, los minutos pospago muestran fluctuaciones considerables entre 2017 y 2020, con picos y caídas en el uso de minutos. Estos cambios pueden deberse a factores como promociones, tarifas de las operadoras, o incluso cambios en las preferencias de los usuarios.
#
# * **Declive notable después de 2020:** A partir de 2020, los minutos pospago comienzan a disminuir de manera notable. Este descenso puede estar relacionado con la creciente adopción de aplicaciones de mensajería y videollamadas, que han sustituido el uso tradicional de llamadas en planes pospago.

# %% [markdown]
# **Minutos Prepago (Línea Naranja)**
#
# * **Estabilidad inicial:** En los primeros años, de 2014 a 2018, los minutos en planes prepago se mantienen relativamente estables. Los usuarios de prepago parecen mantener un uso constante de minutos salientes durante este periodo, lo que sugiere que este grupo de usuarios tenía un patrón de uso más definido.
#
# * **Declive gradual:** A partir de 2018, los minutos prepago comienzan a disminuir de manera constante. Esta tendencia podría estar vinculada a la migración de usuarios prepago hacia otras formas de comunicación, como las aplicaciones de datos móviles (WhatsApp, Telegram, etc.), que ofrecen una alternativa más económica y flexible en comparación con las llamadas tradicionales.
#
# * **Estabilización hacia el final del periodo:** En 2022 y 2023, el uso de minutos prepago parece haberse estabilizado en niveles bajos, sugiriendo que los usuarios que continúan usando este tipo de plan lo hacen de forma limitada y esporádica.

# %% [markdown]
# ## 3.4. Gráfico de dispersión y cálculo de correlación

# %%
import seaborn as sns

# Crear un gráfico de dispersión entre minutos pospago y prepago
plt.figure(figsize=(10, 6))
sns.scatterplot(x=minutos_salientes_df['minutos_pospago_salientes_miles'], y=minutos_salientes_df['minutos_prepago_salientes_miles'])
plt.title('Relación entre minutos pospago y minutos prepago')
plt.xlabel('Minutos Pospago (miles)')
plt.ylabel('Minutos Prepago (miles)')
plt.show()

# Calcular la correlación entre minutos pospago y prepago
correlacion = minutos_salientes_df['minutos_pospago_salientes_miles'].corr(minutos_salientes_df['minutos_prepago_salientes_miles'])
print(f"Correlación entre minutos pospago y prepago: {correlacion}")
# Out:
# Correlación entre minutos pospago y prepago: 0.1425671050749516

# %% [markdown]
# Los minutos prepago y pospago no están correlacionados, lo que implica que las decisiones y promociones para cada tipo de usuario deben ser tratadas de forma separada y adaptada a los comportamientos específicos de cada grupo.

# %% [markdown]
# # **4. Análisis exploratorio hoja `Ingresos`**

# %% [markdown]
# ## 4.1. Carga de la hoja

# %%
# Cargamos la hoja 'Ingresos'
ingresos_df = pd.read_excel('/content/Telefonia_movil_final.xlsx', sheet_name='Ingresos')

# Mostramos las primeras filas para explorar la estructura del dataset
ingresos_df.head()
# Out:
#     año  trimestre  ingresos_miles_de_    periodo
# 0  2013          1            13135235 2013-03-31
# 1  2013          2            13970806 2013-06-30
# 2  2013          3            15235659 2013-09-30
# 3  2013          4            16218846 2013-12-31
# 4  2014          1            15938353 2013-03-31

# %% [markdown]
# ## 4.2. Estadísticas Descriptivas

# %%
# Resumen estadístico del dataset
ingresos_df.describe()
# Out:
#                año  trimestre  ingresos_miles_de_              periodo
# count    45.000000  45.000000        4.500000e+01                   45
# mean   2018.133333   2.466667        1.005241e+08  2018-09-21 21:20:00
# min    2013.000000   1.000000        1.313524e+07  2013-03-31 00:00:00
# 25%    2015.000000   1.000000        2.476305e+07  2015-12-31 00:00:00
# 50%    2018.000000   2.000000        4.328009e+07  2018-09-30 00:00:00
# 75%    2021.000000   3.000000        1.047820e+08  2021-06-30 00:00:00
# max    2024.000000   4.000000        7.694854e+08  2024-03-31 00:00:00
# std       3.286335   1.140175        1.456915e+08                  NaN

# %% [markdown]
# Las estadísticas descriptivas del dataset `Ingresos` proporcionan una visión sobre cómo han evolucionado los ingresos generados por los servicios de telefonía móvil entre 2013 y 2024.

# %% [markdown]
# **Media y Desviación Estándar**
#
# * **Media (Ingresos):** El promedio de ingresos es de $100,52$ millones de pesos ($1.005241e+08$) por trimestre. Este valor proporciona una idea general de los ingresos generados a lo largo del tiempo, pero dada la gran desviación estándar ($145,69$ millones de pesos), podemos inferir que los ingresos han experimentado fluctuaciones significativas a lo largo de los años.
#
# * **Desviación estándar:** La alta desviación estándar refleja que ha habido variabilidad considerable en los ingresos. Esto sugiere que en algunos trimestres los ingresos han sido mucho mayores o menores que el promedio, lo que puede estar relacionado con cambios en la demanda de servicios de telefonía móvil, promociones o tarifas fluctuantes.

# %% [markdown]
# **Valores mínimo y máximo**
#
# * **Mínimo (Ingresos):** El valor mínimo registrado es de $13,13$ millones de pesos en el primer trimestre de 2013. Esto corresponde al inicio del periodo analizado, cuando los ingresos eran más bajos. En ese momento, el mercado de telefonía móvil aún estaba creciendo y la adopción de servicios móviles, como datos y llamadas, era menos intensa.
#
# * **Máximo (Ingresos):** El valor máximo registrado es de $769,49$ millones de pesos en el primer trimestre de 2024. Este incremento masivo en los ingresos puede estar vinculado a una mayor adopción de servicios de telefonía móvil, sobre todo con el auge del consumo de datos móviles y servicios de telecomunicaciones a lo largo del tiempo. También puede haber influido la inflación en el aumento de los precios de los servicios.

# %% [markdown]
# **Tendencias por percentiles**
#
# * **Percentil 25% (Ingresos):** El 25% de los trimestres más bajos tienen ingresos menores a $24,76$ millones de pesos. Esto probablemente corresponde a los primeros años del análisis (2013-2015), cuando los ingresos eran más bajos.
#
# * **Percentil 50% (Mediana de Ingresos):** El ingreso mediano es de $43,28$ millones de pesos. Esto indica que el 50% de los trimestres han generado ingresos superiores a este valor, mientras que el otro 50% ha generado ingresos menores. La mediana es bastante más baja que el promedio ($100$ millones), lo que refuerza la idea de que ha habido un crecimiento considerable en los ingresos en los trimestres más recientes.
#
# * **Percentil 75% (Ingresos):** El 25% de los trimestres con mayores ingresos han generado más de $104,78$ millones de pesos. Esto sugiere que en los trimestres más recientes, o durante algún periodo de auge, los ingresos han crecido considerablemente, probablemente impulsados por una mayor adopción de servicios avanzados de telefonía móvil, como los datos móviles de alta velocidad.

# %% [markdown]
# ## 4.3. Visualización de la evolución de los ingresos a lo largo del tiempo

# %%
# Gráfico de línea para la evolución de los ingresos
plt.figure(figsize=(10, 6))
plt.plot(ingresos_df['periodo'], ingresos_df['ingresos_miles_de_'], marker='o')
plt.title('Evolución de los ingresos por servicios de telefonía móvil')
plt.xlabel('Periodo')
plt.ylabel('Ingresos (miles de pesos)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# La gráfica muestra la evolución de los ingresos por servicios de telefonía móvil desde 2013 hasta 2024, con un crecimiento exponencial hacia los últimos años.

# %% [markdown]
# **Crecimiento Estable hasta 2017**
#
# Desde el inicio del periodo en 2013 hasta alrededor de 2017, los ingresos se mantuvieron relativamente estables, con un aumento muy gradual.
#
# Esto refleja un crecimiento moderado del mercado de telefonía móvil durante esos años, probablemente impulsado por un crecimiento progresivo en la base de usuarios y el uso de servicios de voz y SMS, que eran los más comunes en esa época.
#
# Sin embargo, el crecimiento no fue dramático, lo que podría deberse a la transición lenta hacia la adopción masiva de datos móviles.

# %% [markdown]
# **Aumento acelerado a partir de 2018**
#
# A partir de 2018, observamos un incremento acelerado en los ingresos. Este aumento coincide con la expansión y adopción masiva de servicios de datos móviles de alta velocidad, como 4G y el inicio de la implementación de 5G en algunos países.
#
# El consumo de datos móviles ha crecido exponencialmente, impulsado por la popularidad de aplicaciones como streaming de video, juegos móviles, y videollamadas, que requieren grandes cantidades de datos y han sido adoptados a gran escala por los usuarios.
#
# Además, durante este periodo, es probable que las operadoras de telecomunicaciones hayan comenzado a aumentar los precios de los servicios móviles debido a la mayor demanda y los costos asociados a la infraestructura de datos móviles avanzada.

# %% [markdown]
# **Crecimiento Exponencial en los últimos años (2021-2024)**
#
# Desde 2021, los ingresos muestran un crecimiento exponencial y dramático, con un aumento significativo en el periodo de 2022 a 2024.
#
# Este comportamiento puede estar impulsado por varios factores:
#
# * **Adopción masiva del 5G:** En estos años, la implementación y adopción de la tecnología 5G ha sido más amplia, permitiendo velocidades de conexión más rápidas y mayores capacidades para los usuarios, lo que ha incrementado tanto la demanda como los ingresos generados por las operadoras.
#
# * **Inflación:** En algunos mercados, la inflación ha provocado un aumento en los precios de los servicios de telecomunicaciones, lo que también ha contribuido a un aumento de los ingresos nominales.
#
# * **Crecimiento en la demanda de servicios digitales:** La pandemia de COVID-19 y los cambios en los patrones de trabajo (como el teletrabajo y la mayor dependencia de servicios de streaming y videollamadas) han impulsado la demanda de servicios móviles, lo que ha resultado en un aumento significativo en los ingresos de las empresas de telecomunicaciones.

# %% [markdown]
# **Pico en 2024**
#
# El gráfico muestra un pico impresionante en 2024, donde los ingresos alcanzan los $769,49$ millones de pesos.Este aumento puede estar relacionado con el crecimiento de la infraestructura 5G, el aumento de los costos de los servicios móviles, y una demanda insaciable de datos móviles por parte de los usuarios que utilizan cada vez más servicios intensivos en datos, como el streaming en 4K, la realidad aumentada (AR), la realidad virtual (VR) y los videojuegos en línea.
#
# Las operadoras pueden haber ajustado sus tarifas y planes de servicio para captar esta demanda creciente, lo que ha impulsado aún más los ingresos.

# %% [markdown]
# ## 4.4. Análisis de ingresos por trimestre

# %% [markdown]
# Podemos agrupar los ingresos por trimestre para analizar si hay trimestres que sistemáticamente generan más ingresos.

# %%
# Agrupamos los ingresos por trimestre
ingresos_por_trimestre = ingresos_df.groupby('trimestre')['ingresos_miles_de_'].mean()

# Visualizamos los ingresos promedio por trimestre
plt.figure(figsize=(10, 6))
ingresos_por_trimestre.plot(kind='bar', color='skyblue')
plt.title('Ingresos promedio por trimestre')
plt.xlabel('Trimestre')
plt.ylabel('Ingresos promedio (miles de pesos)')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# El gráfico de ingresos promedio por trimestre muestra una clara estacionalidad en los servicios de telefonía móvil, con el primer trimestre generando los mayores ingresos, superando los $120$ millones de pesos. Esto podría estar vinculado a la renovación de contratos y el mayor uso de servicios tras las festividades de fin de año. En contraste, el segundo trimestre presenta una caída significativa en los ingresos, posiblemente debido a un ajuste en el comportamiento del consumidor después del gasto elevado a inicios de año.
#
# El tercer trimestre muestra una recuperación, con ingresos promedio cercanos a los $90$ millones de pesos, lo que puede estar relacionado con el mayor uso de servicios de telecomunicaciones durante las vacaciones de verano en muchos países. Finalmente, el cuarto trimestre vuelve a experimentar un aumento, alcanzando cerca de $110$ millones de pesos en promedio, impulsado por las festividades de fin de año y las promociones de las operadoras móviles.
